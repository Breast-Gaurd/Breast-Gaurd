# %% [markdown]
# ### Submitted by: A.P.Swathi Lakshmi - 20MIS0091 (VIT Vellore)

# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Download the dataset: 'titanic' --- Downloaded successfully

# %% [markdown]
# ### 2. Load the dataset.

# %%
data=pd.read_csv('titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ### 3. Perform below visualizations.

# %% [markdown]
# ### Univariate Analysis

# %%
# Using figure to plot histograms for age and fare column (continuous data)
plt.figure(figsize=(10,8))

# histogram for age column
plt.subplot(2,1,1)
plt.hist(data['age'])
plt.xlabel('age')
plt.ylabel('age_count')

# histogram for fare column
plt.subplot(2,1,2)
plt.hist(data['fare'],color='red')
plt.xlabel('fare')
plt.ylabel('fare_count')
# Out:
# Text(0, 0.5, 'fare_count')

# %%
# Using figure to plot line plot for age and fare columns
plt.figure(figsize=(10,6))

# Line plot for age column
plt.subplot(2,2,1)
plt.plot(data['age'])
plt.xlabel('age')

# Line plot for fare column
plt.subplot(2,2,2)
plt.plot(data['fare'])
plt.xlabel('fare')
# Out:
# Text(0.5, 0, 'fare')

# %%
# Using figure to plot pie charts for sex and embark_town (categorical data)

plt.figure(figsize=(10,6))

# pie chart for sex column
sex=data['sex'].value_counts()
sex_labels=data['sex'].unique()
plt.subplot(1,2,1)
plt.pie(sex,autopct='%.2f',labels=sex_labels)
plt.title('Sex')

# pie chart for class column
class1=data['class'].value_counts()
class_labels=data['class'].unique()
plt.subplot(1,2,2)
plt.pie(class1,autopct='%.2f',labels=class_labels)
plt.title('Class')
# Out:
# Text(0.5, 1.0, 'Class')

# %%
# Using figure to plot distribution plots for pclass and survived columns
plt.figure(figsize=(10,6))

# distribution plot for pclass column
plt.subplot(1,2,1)
sns.distplot(data['pclass'])
plt.title('pclass')

# distribution plot for survived column
plt.subplot(1,2,2)
sns.distplot(data['survived'])
plt.title('survived')
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\1897906649.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['pclass'])
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\1897906649.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['survived'])
# ...

# %% [markdown]
# ### Bi - Variate Analysis

# %%
# Line plot for age vs fare columns

plt.plot(data['age'], data['fare'])
plt.xlabel('age')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
# Scatter plot for age vs fare columns

plt.scatter(data['age'],data['fare'])
plt.title('age vs sex comparison')
plt.xlabel('age')
plt.ylabel('fare')
# Out:
# Text(0, 0.5, 'fare')

# %%
# Using figure to plot bar charts

plt.figure(figsize=(10,6))

# Bar chart for sex vs age column
plt.subplot(1,2,1)
plt.bar(data['sex'], data['age'])
plt.xlabel('sex')
plt.ylabel('age')
plt.title('sex vs age')

# Bar chart for class vs fare column
plt.subplot(1,2,2)
plt.bar(data['class'],data['fare'])
plt.xlabel('class')
plt.ylabel('fare')
plt.title('class vs fare')
# Out:
# Text(0.5, 1.0, 'class vs fare')

# %% [markdown]
# ### Multi-variate analysis

# %%
#  Plotting Heat map
hm=data.corr()
sns.heatmap(hm)
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\105229327.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm=data.corr()
# <Axes: >

# %%
# Plotting Pair plot
sns.pairplot(data)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# ### 4. Perform descriptive statistics on the dataset.

# %% [markdown]
# #### Measures of Central Tendency

# %%
# MEAN
print(data.mean())
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\1841345841.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.mean())

# %%
# MEDIAN
print(data.median())
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\756934764.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.median())

# %%
# MODE
print(data.mode())
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
# SKEWNESS
print(data.skew())
# Out:
# survived      0.478523
# pclass       -0.630548
# age           0.389108
# sibsp         3.695352
# parch         2.749117
# fare          4.787317
# adult_male   -0.420431
# alone        -0.420431
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\2773987728.py:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.skew())

# %%
# KURTOSIS
print(data.kurt())
# Out:
# survived      -1.775005
# pclass        -1.280015
# age            0.178274
# sibsp         17.880420
# parch          9.778125
# fare          33.398141
# adult_male    -1.827345
# alone         -1.827345
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\3730950502.py:2: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.kurt())

# %% [markdown]
# #### Measures of Variability

# %%
# STANDARD DEVIATION
print(data.std())
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\1931870834.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.std())
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
# VARIANCE
print(data.var())
# Out:
# survived         0.236772
# pclass           0.699015
# age            211.019125
# sibsp            1.216043
# parch            0.649728
# fare          2469.436846
# adult_male       0.239723
# alone            0.239723
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_17892\1609406345.py:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.var())

# %% [markdown]
# ### 5. Handle the missing values.

# %%
# Checking for null values
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age             True
# sibsp          False
# parch          False
# fare           False
# embarked        True
# class          False
# who            False
# adult_male     False
# deck            True
# embark_town     True
# alive          False
# alone          False
# dtype: bool

# %%
# Filling the missing values in age column using mean, because age is a numerical value
data['age'].fillna(data['age'].median(),inplace=True)

# %%
# Filling the missing values in embarked column, because embarked is categorical
data['embarked'].fillna(data['embarked'].mode()[0],inplace=True)

# %%
# Filling the missing values in deck column, because deck is categorical
data['deck'].fillna(data['deck'].mode()[0],inplace=True)

# %%
# Filling the missing values in embark_town column, because embark_town is categorical
data['embark_town'].fillna(data['embark_town'].mode()[0],inplace=True)

# %%
# Checking for null values after imputation
data.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked       False
# class          False
# who            False
# adult_male     False
# deck           False
# embark_town    False
# alive          False
# alone          False
# dtype: bool

# %%
# Thus, the imputation is successful.

# %% [markdown]
# ### 6. Find the outliers and replace the outliers.

# %%
# Outlier detection in age column
sns.boxplot(data['age'])
# Out:
# <Axes: >

# %%
# Outlier removal in age column

# %%
perc99=data['age'].quantile(0.99)

# %%
data=data[data['age']<=perc99]
sns.boxplot(data['age'])
# Out:
# <Axes: >

# %%
# Outlier detection in fare column
sns.boxplot(data['fare'])
# Out:
# <Axes: >

# %%
# Outlier removal in fare column
perc99=data['fare'].quantile(0.99)
perc99
# Out:
# 262.375

# %%
data=data[data['fare']<=perc99]
sns.boxplot(data['fare'])
# Out:
# <Axes: >

# %% [markdown]
# ### 7. Check for categorical columns and perform encoding.

# %%
# Label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
# Performing label encoding on sex column
data.sex=le.fit_transform(data.sex)

# %%
# Performing label encoding on who column
data.who=le.fit_transform(data.who)

# %%
# Performing label encoding on embarked column
data.embarked=le.fit_transform(data.embarked)

# %%
# Performing label encoding on class column
data['class']=le.fit_transform(data['class'])

# %%
# Performing label encoding on adult_male column
data.adult_male=le.fit_transform(data.adult_male)

# %%
# Peforming label encoding on deck column
data.deck=le.fit_transform(data.deck)

# %%
# Performing label encoding on embark_town column
data.embark_town=le.fit_transform(data.embark_town)

# %%
# Performing label encoding on alive column
data.alive=le.fit_transform(data.alive)

# %%
# Peforming label encoding on alone column
data.alone=le.fit_transform(data.alone)

# %%
# Printing the dataset
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0           0       3    1  22.0      1      0   7.2500         2      2    1
# 1           1       1    0  38.0      1      0  71.2833         0      0    2
# 2           1       3    0  26.0      0      0   7.9250         2      2    2
# 3           1       1    0  35.0      1      0  53.1000         2      0    2
# 4           0       3    1  35.0      0      0   8.0500         2      2    1
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...  ...
# 886         0       2    1  27.0      0      0  13.0000         2      1    1
# 887         1       1    0  19.0      0      0  30.0000         2      0    2
# 888         0       3    0  28.0      1      2  23.4500         2      2    2
# 889         1       1    1  26.0      0      0  30.0000         0      0    1
# 890         0       3    1  32.0      0      0   7.7500         1      2    1
#
# ...

# %% [markdown]
# ### 8. Split the data into dependent and independent variables.

# %%
# Y is the dependent variable - "survived" class label

Y=data['survived']
Y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
# X is the independent variables 

X=data.drop(columns=['survived'],axis=1)
X.head()
# Out:
#    pclass  sex   age  sibsp  parch     fare  embarked  class  who  adult_male  \
# 0       3    1  22.0      1      0   7.2500         2      2    1           1
# 1       1    0  38.0      1      0  71.2833         0      0    2           0
# 2       3    0  26.0      0      0   7.9250         2      2    2           0
# 3       1    0  35.0      1      0  53.1000         2      0    2           0
# 4       3    1  35.0      0      0   8.0500         2      2    1           1
#
#    deck  embark_town  alive  alone
# 0     2            2      0      0
# 1     2            0      1      0
# 2     2            2      1      1
# 3     2            2      1      0
# 4     2            2      0      1

# %% [markdown]
# ### 9. Scale the independent variables.

# %%
# Using MinMax scaling technique:
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X_scaled=scale.fit_transform(X)
X_scaled
# Out:
# array([[1.        , 1.        , 0.33415918, ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.58191391, ..., 0.        , 1.        ,
#         0.        ],
#        [1.        , 0.        , 0.39609786, ..., 1.        , 1.        ,
#         1.        ],
#        ...,
#        [1.        , 0.        , 0.4270672 , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.39609786, ..., 0.        , 1.        ,
#         1.        ],
#        [1.        , 1.        , 0.48900588, ..., 0.5       , 0.        ,
#         1.        ]])

# %%
name=X.columns
print(name)
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class',
#        'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
X=pd.DataFrame(X_scaled,columns=name)
X   # printing Scaled independent variables
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  class  who  \
# 0       1.0  1.0  0.334159  0.125  0.000000  0.029290       1.0    1.0  0.5
# 1       0.0  0.0  0.581914  0.125  0.000000  0.287989       0.0    0.0  1.0
# 2       1.0  0.0  0.396098  0.000  0.000000  0.032018       1.0    1.0  1.0
# 3       0.0  0.0  0.535460  0.125  0.000000  0.214527       1.0    0.0  1.0
# 4       1.0  1.0  0.535460  0.000  0.000000  0.032523       1.0    1.0  0.5
# ..      ...  ...       ...    ...       ...       ...       ...    ...  ...
# 869     0.5  1.0  0.411583  0.000  0.000000  0.052521       1.0    0.5  0.5
# 870     0.0  0.0  0.287705  0.000  0.000000  0.121202       1.0    0.0  1.0
# 871     1.0  0.0  0.427067  0.125  0.333333  0.094740       1.0    1.0  1.0
# 872     0.0  1.0  0.396098  0.000  0.000000  0.121202       0.0    0.0  0.5
# 873     1.0  1.0  0.489006  0.000  0.000000  0.031310       0.5    1.0  0.5
#
#      adult_male      deck  embark_town  alive  alone
# ...

# %% [markdown]
# ### 10. Split the data into training and testing.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# X_train values
X_train.head()
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  class  who  \
# 54      0.5  0.0  0.318675  0.000  0.000000  0.042421       1.0    0.5  1.0
# 45      1.0  0.0  0.427067  0.000  0.000000  0.031310       0.5    1.0  1.0
# 172     0.0  0.0  0.767730  0.000  0.000000  0.116000       0.0    0.0  1.0
# 538     1.0  1.0  0.504491  0.125  0.166667  0.082922       1.0    1.0  0.5
# 819     0.0  0.0  0.597399  0.125  0.166667  0.335965       0.0    0.0  1.0
#
#      adult_male      deck  embark_town  alive  alone
# 54          0.0  0.333333          1.0    1.0    1.0
# 45          0.0  0.333333          0.5    1.0    1.0
# 172         0.0  0.333333          0.0    0.0    1.0
# 538         1.0  0.333333          1.0    0.0    0.0
# 819         0.0  0.666667          0.0    1.0    0.0

# %%
# X_test values
X_test.head()
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  class  who  \
# 141     1.0  1.0  0.411583  0.000  0.000000  0.031496       1.0    1.0  0.5
# 113     0.0  1.0  0.365129  0.000  0.166667  1.000000       0.0    0.0  0.5
# 729     1.0  1.0  0.473521  0.000  0.000000  0.032018       1.0    1.0  0.5
# 294     1.0  0.0  0.427067  0.000  0.000000  0.031310       0.5    1.0  1.0
# 261     1.0  1.0  0.380613  0.125  0.000000  0.031412       1.0    1.0  0.5
#
#      adult_male      deck  embark_town  alive  alone
# 141         1.0  0.333333          1.0    1.0    1.0
# 113         1.0  0.166667          0.0    0.0    0.0
# 729         1.0  0.333333          1.0    1.0    1.0
# 294         0.0  0.333333          0.5    1.0    1.0
# 261         1.0  0.333333          1.0    1.0    0.0

# %%
# Y_train values
Y_train.head()
# Out:
# 56     1
# 47     1
# 177    0
# 548    0
# 835    1
# Name: survived, dtype: int64

# %%
# Y_test values
Y_test.head()
# Out:
# 146    1
# 118    0
# 744    1
# 300    1
# 267    1
# Name: survived, dtype: int64
