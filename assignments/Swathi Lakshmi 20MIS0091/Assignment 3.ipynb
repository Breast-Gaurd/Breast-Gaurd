# %% [markdown]
# ## Submitted by: A P Swathi Lakshmi - 20MIS0091 (VIT Vellore)

# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Download the dataset: 'Housing.csv' --- Downloaded successfully.

# %% [markdown]
# ### 2. Load the dataset into the tool.

# %%
data=pd.read_csv('Housing.csv')
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
data.shape
# Out:
# (545, 12)

# %% [markdown]
# ### 3. Perform below visulaizations.

# %% [markdown]
# ### Univariate Analysis

# %%
# Using figure to plot histograms for price, area, bedrooms, and bathrooms columns

plt.figure(figsize=(10,8))

# histogram for price column
plt.subplot(2,2,1)
plt.hist(data['price'])
plt.xlabel('price')
plt.ylabel('price_Count')

#histogram for area column
plt.subplot(2,2,2)
plt.hist(data['area'])
plt.xlabel('area')
plt.ylabel('area_count')

# histogram for bedrooms column
plt.subplot(2,2,3)
plt.hist(data['bedrooms'])
plt.xlabel('bedrooms')
plt.ylabel('bedrooms_count')

# histogram for bathrooms column
plt.subplot(2,2,4)
plt.hist(data['bathrooms'])
plt.xlabel('bathrooms')
plt.ylabel('bathrooms_count')
# Out:
# Text(0, 0.5, 'bathrooms_count')

# %%
# Using figure to plot line plot for price, area, stories and parking columns

plt.figure(figsize=(10,8))

# Line plot for price column
plt.subplot(2,2,1)
plt.plot(data['price'])
plt.xlabel('price')

# Line plot for area column
plt.subplot(2,2,2)
plt.plot(data['area'])
plt.xlabel('area')

# Line plot for stories column
plt.subplot(2,2,3)
plt.plot(data['stories'])
plt.xlabel('stories')

# Line plot for parking column
plt.subplot(2,2,4)
plt.plot(data['parking'])
plt.xlabel('parking')
# Out:
# Text(0.5, 0, 'parking')

# %%
# Using figure to plot pie charts for basement and furnishingstatus columns (categorical columns)

plt.figure(figsize=(10,4))

# Pie chart for basement column
basement=data['basement'].value_counts()
basement_labels=data['basement'].unique()
plt.subplot(1,2,1)
plt.pie(basement, autopct='%.2f', labels=basement_labels)
plt.title('Basement')

# Pie chart for furnishingstatus column
furnishing=data['furnishingstatus'].value_counts()
furnishing_labels=data['furnishingstatus'].unique()
plt.subplot(1,2,2)
plt.pie(furnishing, autopct='%.2f', labels=furnishing_labels)
plt.title('Furnishing Status')
# Out:
# Text(0.5, 1.0, 'Furnishing Status')

# %%
# Using figure to plot distribution plots for price and stories columns

plt.figure(figsize=(10,6))

# Distribution plot for price column (numerical)
plt.subplot(1,2,1)
sns.distplot(data['price'])
plt.title('Price')

# Distribution plot for stories column (categorical)
plt.subplot(1,2,2)
sns.distplot(data['stories'])
plt.title('Stories')
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\2801925179.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['price'])
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\2801925179.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['stories'])
# ...

# %% [markdown]
# ### Bi - Variate Analysis

# %%
# Using figure to plot line plots for bi-variate analysis

plt.figure(figsize=(10,6))

# Line plot for bedrooms vs price column
plt.subplot(1,2,1)
plt.plot(data['price'],data['bedrooms'],color='orange')
plt.xlabel('price')
plt.ylabel('bedrooms')

# Line plot for bathrooms vs area column
plt.subplot(1,2,2)
plt.plot(data['area'], data['bathrooms'], color='blue')
plt.xlabel('area')
plt.ylabel('bathrooms')
# Out:
# Text(0, 0.5, 'bathrooms')

# %%
# Using figure to plot scatter plot for bi-variate analysis

plt.figure(figsize=(10,6))

# Scatter plot for price vs parking columns
plt.subplot(1,2,1)
plt.scatter(data['price'], data['parking'])
plt.xlabel('price')
plt.ylabel('parking')

# Scatter plot for area vs parking columns
plt.subplot(1,2,2)
plt.scatter(data['area'], data['parking'], color='red')
plt.xlabel('area')
plt.ylabel('parking')
# Out:
# Text(0, 0.5, 'parking')

# %%
# Using figure for plotting bar plots for bi-variate analysis

plt.figure(figsize=(10,6))

# Bar plot for basement vs area columns (categorical vs numerical)
plt.subplot(1,2,1)
plt.bar(data.basement,data.area)
plt.xlabel('basement')
plt.ylabel('area')

# Bar plot for bathrooms vs price columns (numerical vs categorical)
plt.subplot(1,2,2)
plt.bar(data.bathrooms, data.price, color='green')
plt.xlabel('bathrooms')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# ### Multi - Variate Analysis

# %%
# Plotting Heat Map
hm=data.corr()
sns.heatmap(hm)
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\2432554754.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm=data.corr()
# <Axes: >

# %%
# Plotting Pair Plot 
sns.pairplot(data)

# %% [markdown]
# ### 4. Perform descriptive statistics on the dataset.

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# #### Measures of central tendency

# %%
# MEAN
print(data.mean())
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\1841345841.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.mean())

# %%
# MEDIAN
print(data.median())
# Out:
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\756934764.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.median())

# %%
# MODE
print(data.mode())
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
# SKEWNESS
print(data.skew())
# Out:
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\2773987728.py:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.skew())
# price        1.212239
# area         1.321188
# bedrooms     0.495684
# bathrooms    1.589264
# stories      1.082088
# parking      0.842062
# dtype: float64

# %%
# KURTOSIS
print(data.kurt())
# Out:
# price        1.960130
# area         2.751480
# bedrooms     0.728323
# bathrooms    2.164856
# stories      0.679404
# parking     -0.573063
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\3730950502.py:2: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.kurt())

# %% [markdown]
# #### Measures of Variability

# %%
# INTER-QUARTILE RANGE - (IQR)

quantile=data.quantile(q=[0.75,0.25])
print('\n'+'Quantile: ')
print(quantile)

#IQR
IQR=quantile.iloc[0]-quantile.iloc[1]
print('\n'+'Inter Quantile Range: ')
print(IQR)

#upper extreme=Q3 +1.5 * IQR
upper_extreme=quantile.iloc[0]+(1.5*IQR)
print('\n'+'Upper extreme: ')
print(upper_extreme)

#lower extreme=Q1 -1.5 * IQR
lower_extreme=quantile.iloc[1]-(1.5* IQR)
print('\n'+'Lower extreme: ')
print(lower_extreme)
# Out:
# Quantile:
#           price    area  bedrooms  bathrooms  stories  parking
# 0.75  5740000.0  6360.0       3.0        2.0      2.0      1.0
# 0.25  3430000.0  3600.0       2.0        1.0      1.0      0.0
#
# Inter Quantile Range:
# price        2310000.0
# area            2760.0
# bedrooms           1.0
# bathrooms          1.0
# stories            1.0
# parking            1.0
# dtype: float64
#
# Upper extreme:
# price        9205000.0
# area           10500.0
# bedrooms           4.5
# bathrooms          3.5
# stories            3.5
# parking            2.5
# dtype: float64
#
# Lower extreme:
# price       -35000.0
# area          -540.0
# bedrooms         0.5
# bathrooms       -0.5
# stories         -0.5
# parking         -1.5
# dtype: float64
# ...

# %%
# Using figure to plot the box plots for the numerical columns to analyse IQR

plt.figure(figsize=(10,6))

#price column
plt.subplot(1,2,1)
sns.boxplot(data.price)
plt.title('Price')

#area column
plt.subplot(1,2,2)
sns.boxplot(data.area)
plt.title('Area')
# Out:
# Text(0.5, 1.0, 'Area')

# %%
# STANDARD DEVIATION
print(data.std())
# Out:
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\1931870834.py:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.std())

# %%
# VARIANCE
print(data.var())
# Out:
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64
# C:\Users\swath\AppData\Local\Temp\ipykernel_11072\1609406345.py:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.var())

# %% [markdown]
# ### 5. Check for missing values and deal with them.

# %%
# Checking for null values
data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# Thus, there are no missing values in the 'Housing.csv' dataset.

# %% [markdown]
# ### 6. Find the outliers and replace the outliers.

# %%
# Using figure to plot the box plots for the numerical columns to visualize the outliers.

plt.figure(figsize=(12,8))

#price column
plt.subplot(2,3,1)
sns.boxplot(data.price)
plt.title('Price')

#area column
plt.subplot(2,3,2)
sns.boxplot(data.area)
plt.title('Area')

#bedrooms column
plt.subplot(2,3,3)
sns.boxplot(data.bedrooms)
plt.title('Bedrooms')

#bathrooms column
plt.subplot(2,3,4)
sns.boxplot(data.bathrooms)
plt.title('Bathrooms')

#stories column
plt.subplot(2,3,5)
sns.boxplot(data.stories)
plt.title('Stories')

#parking column
plt.subplot(2,3,6)
sns.boxplot(data.parking)
plt.title('Parking')
# Out:
# Text(0.5, 1.0, 'Parking')

# %%
# Removing autliers

# Price column
data=data[data.price<9205000]  # 9095625 is the upper extreme of the price column

# Area column
data=data[data.area<10500]  # 10500 is the upper extreme of the area column

# %%
# Visualizing the outliers after treating them.

plt.figure(figsize=(10,4))

#price column
plt.subplot(1,2,1)
sns.boxplot(y='price', data=data)

#area column
plt.subplot(1,2,2)
sns.boxplot(y='area', data=data)
# Out:
# <Axes: ylabel='area'>

# %%
data.shape
# Out:
# (517, 12)

# %% [markdown]
# ### 7. Check for categorical columns and perform encoding.

# %%
# Performing Label Encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# Dataset before categorical columns were encoded
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 15  9100000  6000         4          1        2      yes        no      yes
# 16  9100000  6600         4          2        2      yes       yes      yes
# 17  8960000  8500         3          2        4      yes        no       no
# 18  8890000  4600         3          2        2      yes       yes       no
# 19  8855000  6420         3          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking furnishingstatus
# 15              no              no        2   semi-furnished
# 16              no             yes        1      unfurnished
# 17              no             yes        2        furnished
# 18              no             yes        2        furnished
# 19              no             yes        1   semi-furnished

# %%
# Label encoding for mainroad column
data.mainroad=le.fit_transform(data.mainroad)

# Label encoding for guestroom column
data.guestroom=le.fit_transform(data.guestroom)

# Label encoding for basement column
data.basement=le.fit_transform(data.basement)

# Label encoding for hotwaterheating column
data.hotwaterheating=le.fit_transform(data.hotwaterheating)

# Label encoding for airconditioning column
data.airconditioning=le.fit_transform(data.airconditioning)

# Label encoding for furnishingstatus column
data.furnishingstatus=le.fit_transform(data.furnishingstatus)

# %%
# Dataset after performing label encoding for categorical columns
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 15  9100000  6000         4          1        2         1          0
# 16  9100000  6600         4          2        2         1          1
# 17  8960000  8500         3          2        4         1          0
# 18  8890000  4600         3          2        2         1          1
# 19  8855000  6420         3          2        2         1          0
#
#     basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 15         1                0                0        2                 1
# 16         1                0                1        1                 2
# 17         0                0                1        2                 0
# 18         0                0                1        2                 0
# 19         0                0                1        1                 1

# %% [markdown]
# ### 8. Split the data into dependent and independent variables.

# %%
# Y is the dependent variable - "price" class label

Y=data['price']
Y.head()
# Out:
# 15    9100000
# 16    9100000
# 17    8960000
# 18    8890000
# 19    8855000
# Name: price, dtype: int64

# %%
# X is the independent variables 

X=data.drop(columns=['price'],axis=1)
X.head()
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 15  6000         4          1        2         1          0         1
# 16  6600         4          2        2         1          1         1
# 17  8500         3          2        4         1          0         0
# 18  4600         3          2        2         1          1         0
# 19  6420         3          2        2         1          0         0
#
#     hotwaterheating  airconditioning  parking  furnishingstatus
# 15                0                0        2                 1
# 16                0                1        1                 2
# 17                0                1        2                 0
# 18                0                1        2                 0
# 19                0                1        1                 1

# %% [markdown]
# ### 9. Scale the independent variables.

# %%
# Using MinMax scaling technique:

from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X_scaled=scale.fit_transform(X)
X_scaled
# Out:
# array([[0.49942595, 0.6       , 0.        , ..., 0.        , 0.66666667,
#         0.5       ],
#        [0.56831228, 0.6       , 0.5       , ..., 1.        , 0.33333333,
#         1.        ],
#        [0.78645235, 0.4       , 0.5       , ..., 1.        , 0.66666667,
#         0.        ],
#        ...,
#        [0.22617681, 0.2       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.14466131, 0.4       , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.25258324, 0.4       , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
name=X.columns
print(name)
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking',
#        'furnishingstatus'],
#       dtype='object')

# %%
# printing Scaled independent variables

X=pd.DataFrame(X_scaled,columns=name)
X
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0    0.499426       0.6        0.0  0.333333       1.0        0.0       1.0
# 1    0.568312       0.6        0.5  0.333333       1.0        1.0       1.0
# 2    0.786452       0.4        0.5  1.000000       1.0        0.0       0.0
# 3    0.338691       0.4        0.5  0.333333       1.0        1.0       0.0
# 4    0.547646       0.4        0.5  0.333333       1.0        0.0       0.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 512  0.154994       0.2        0.0  0.000000       1.0        0.0       1.0
# 513  0.086108       0.4        0.0  0.000000       0.0        0.0       0.0
# 514  0.226177       0.2        0.0  0.000000       1.0        0.0       0.0
# 515  0.144661       0.4        0.0  0.000000       0.0        0.0       0.0
# 516  0.252583       0.4        0.0  0.333333       1.0        0.0       0.0
#
# ...

# %% [markdown]
# ### 10. Split the data into training and testing.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# X_train values

X_train

# %%
# X_test values

X_test

# %%
# Y_train values

Y_train

# %%
# Y_test values

Y_test

# %% [markdown]
# ### 11. Build the model.

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

# %% [markdown]
# ### 12. Train the model.

# %%
lr.fit(X_train,Y_train)

# %% [markdown]
# ### 13. Test the model.

# %%
# Prediction
Y_pred=lr.predict(X_test)
Y_pred

# %%
# Actual Outcome
Y_test

# %% [markdown]
# ### 14. Measure the performance using metrics.

# %%
# Finding the ERROR

E=Y_test-Y_pred
E

# %%
# R2 score

from sklearn.metrics import r2_score
acc=r2_score(Y_test,Y_pred)
print('Accuracy percentage: ')
print(acc*100)
